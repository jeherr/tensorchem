# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
with open("/mnt/sdb1/adriscoll/chemspider_data/expanded_msets/all_opt_scores.npy", "rb") as f:
    opt_scores = np.load(f)

# %%
with open("/mnt/sdb1/adriscoll/chemspider_data/expanded_msets/all_meta_scores.npy", "rb") as f:
    meta_scores = np.load(f)

# %%
with open("/mnt/sdb1/adriscoll/ani1x-data/all_ani_scores.npy", "rb") as f:
    ani_scores = np.load(f)

# %%
with open("/mnt/sdb1/adriscoll/gdb9-data/all_gdb9_scores.npy", "rb") as f:
    gdb9_scores = np.load(f)

# %%
with open("/mnt/sdb1/adriscoll/chemspider_data/expanded_msets/opt_subset3000_scores.npy", "rb") as f:
    opt_sub_scores = np.load(f)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.set_size_inches(10.5, 10.5)

opt_plot = ax1.matshow(opt_scores)
ax1.set_title("Chemspider Opt Data - Similarity Scores", y=1.1)
plt.colorbar(opt_plot,ax=ax1)

meta_plot = ax2.matshow(meta_scores)
ax2.set_title("Chemspider Meta Data - Similarity Scores", y=1.1)
plt.colorbar(meta_plot,ax=ax2)

ani_plot = ax3.matshow(ani_scores)
ax3.set_title("ANI Data - Similarity Scores", y=1.1)
plt.colorbar(ani_plot,ax=ax3)

gdb9_plot = ax4.matshow(gdb9_scores)
ax4.set_title("GDB-9 Data - Similarity Scores", y=1.1)
plt.colorbar(gdb9_plot,ax=ax4)

fig.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(12.5, 4.5)

opt_plot = ax1.matshow(opt_scores)
ax1.set_title("Chemspider Opt Data - Similarity Scores", y=1.1)
plt.colorbar(opt_plot,ax=ax1)

opt_sub_plot = ax2.matshow(opt_sub_scores)
ax2.set_title("Chemspider Opt Data - Similarity Scores - 3000 Molecule Subset", y=1.1)
plt.colorbar(meta_plot,ax=ax2)

fig.tight_layout()
plt.show()
